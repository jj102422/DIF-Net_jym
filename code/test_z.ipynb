# %%
import sys
import numpy as np
sys.path.append('./code')
from dataset import CBCT_dataset
print("🚀 [Step 1] 启动 Eval 模式验证 (Index=1)...")
# 确保使用 knee_cbct (或你修改过白名单的名字)
ds_eval = CBCT_dataset(dst_name='knee_cbct', split='eval', out_res=512)
_ = ds_eval[1] # 触发断点！

print("\n🚀 [Step 2] 启动 Train 模式验证 (Index=1)...")
ds_train = CBCT_dataset(dst_name='knee_cbct', split='train', out_res=512, npoint=100)
_ = ds_train[1] # 触发断点！
# Out:
# 🚀 [Step 1] 启动 Eval 模式验证 (Index=1)...
# CBCT_dataset, name: knee_cbct, split: eval, len: 6.
# Loaded Z-lengths for 865 patients.
# Traceback (most recent call last):
#   File "_pydevd_bundle/pydevd_cython.pyx", line 1078, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle/pydevd_cython.pyx", line 297, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend
#   File "/root/aicp-data/yes/envs/perx2ct/lib/python3.8/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 1976, in do_wait_suspend
#     keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#   File "/root/aicp-data/yes/envs/perx2ct/lib/python3.8/site-packages/debugpy/_vendored/pydevd/pydevd.py", line 2011, in _do_wait_suspend
#     time.sleep(0.01)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
